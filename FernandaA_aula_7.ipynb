# %% [markdown]
# <a href="https://colab.research.google.com/github/fernanda0402/Python/blob/master/FernandaA_aula_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Parte 1**

# %% [markdown]
# Exercício 1: A conjectura de Collatz, diz que "Todos os inteiros positivos irão eventualmente convergir para 1 usando as regras do Collatz". Faça um programa que verifique a conjectura de Collatz para alguns valores. As regras de Collatz são: Dado um número n:
#
# *   se n for par, divida-o por 2;
# *   Se n for ímpar, atualize-o para 3*n + 1

# %%
n = int(input('Digite um número inteiro: '))

while (n > 1):
    if n%2 == 0:
        n = n/2
    else:
        n = 3*n + 1
    print(n)

# %% [markdown]
# Exercício 2: Modifique a função counter para contar o número de vezes que os dígitos 0 e 5 aparecem em um dado número n. Por exemplo, n = 10568, tem 2 dígitos 0 ou 5.

# %%
def counter(n):
    count = 0
    while n!=0:
      if n%10 == 0 or n%10 == 5:
          count = count + 1
      n = n // 10
    return count

counter(10568)

# %% [markdown]
# Exercício 3: Encapsule e generalize a seguinte declaração:

# %%
#Declaração a ser encapsulada e generalizada
for i in [12, 16, 17, 24, 29]:
    if i % 2 == 1:  # If the number is odd
       break        #  ... immediately exit the loop
    print(i)
print("done")

# %%
#Resolução
def checar_impares(numeros):
    for n in numeros:
        if n%2 == 1:
          break
        print(n)
    print('Fim')

checar_impares([12,16,17,24,29])

# %% [markdown]
# Exercício 4: O método de Newton para raiz quadrada. Suponha que você queira calcular a raiz quadrada de n. Se você começar com quase qualquer aproximação, poderá calcular uma aproximação melhor (mais próxima da resposta real) com a seguinte fórmula: melhor = (approx + n/approx)/2
#
# Usando um loop e repetindo esta fórmula até que a melhor aproximação se aproxime o suficiente da anterior (podemos considerar uma diferença de 0,001), podemos escrever uma função para calcular a raiz quadrada.

# %%
def newton(n):
    approx = n/2.5
    count = 0
    while True:
      count = count + 1
      melhor = (approx + n/approx)/2
      if approx - melhor == 0:
        return melhor, count
      approx = melhor

n = int(input('Digite um número inteiro: '))
raiz, count = newton(n)

print('A raiz quadrada é', round(raiz, 2))
print('O número de repetições foi', count)

# %% [markdown]
# ## **Parte 2**

# %% [markdown]
# Exercício 1: O módulo time fornece uma função, também chamada time, que devolve a Hora Média de Greenwich na “época”, que é um momento arbitrário usado como ponto de referência. Em sistemas UNIX, a época é primeiro de janeiro de 1970.

# %%
import time
time.time()

# %% [markdown]
# Escreva um script que leia a hora atual e a converta em um tempo em horas, minutos e segundos, mais o número de dias desde a época.

# %%
import time
t = time.time()

def segundos(t):
    s = t % 60
    return s

def minutos(t):
    min = t/60
    return min

def hora_resto(min):
    h_r = min % 60
    return h_r

def hora(min):
    h = min/60
    return h

def dia_resto(h):
    d_r = hora % 24
    return d_r

def dia(h):
    d = h/24
    return d

def ano_resto(d):
    ano_r = dia % 365
    return ano_r

def ano(d):
    a = dia/365
    return a

s = segundos(t)
min = minutos(t)
h_r = hora_resto(min)
h = hora(min)
d_r = dia_resto(h)
d = dia(h)
ano_r = ano_resto(d)
a = ano(d)
print(a)

# %% [markdown]
# Exercício 2: O último teorema de Fermat diz que não existem números inteiros a, b e c tais que $a**n + b**n == c**n$ para quaisquer valores de n maiores que 2.
#
# A) Escreva uma função chamada check_fermat que receba quatro parâmetros – a, b, c e n – e verifique se o teorema de Fermat se mantém. Se n for maior que 2 e a**n + b**n == c**n o programa deve imprimir, “Holy smokes, Fermat was wrong!” Senão o programa deve exibir “No, that doesn’t work.”
#
# B) Escreva uma função que peça ao usuário para digitar valores para a, b, c e n, os converta em números inteiros e use check_fermat para verificar se violam o teorema de Fermat.

# %%
import math

a = int(input('Digite um número inteiro: '))
b = int(input('Digite um número inteiro: '))
n = int(input('Digite um número inteiro: '))

c = math.pow(a**n + b**n,n)

print(c.is_integer())
print(type(c),c)

def check_fermat(a,b,c,n):
    if n <= 2:
        print('Fermat trata apenas de valores maiores do que 2')
    elif (not(c.is_integer())):
        print('c não é inteiro')
    elif (a**n + b**n == c**n):
      print('Holy smokes, Fermat was wrong')
    else:
      print('No, that does not work')

check_fermat(a,b,c,n)
# Out:
# Digite um número inteiro: 3
# Digite um número inteiro: 4
# Digite um número inteiro: 3
# True
# <class 'float'> 753571.0
# No, that does not work

# %% [markdown]
# Exercício 3: Há um teste simples para ver se é possível formar um triângulo para quaisquer três comprimentos: Se algum dos três comprimentos for maior que a soma dos outros dois, então você não pode formar um triângulo. Senão, você pode. (Se a soma de dois comprimentos igualar o terceiro, eles formam um triângulo chamado “degenerado”.)
#
# A) Escreva uma função chamada is_triangle que receba três números inteiros como argumentos, e que imprima “Yes” ou “No”, dependendo da possibilidade de formar ou não um triângulo de gravetos com os comprimentos dados.
#
# B) Escreva uma função que peça ao usuário para digitar três comprimentos de gravetos, os converta em números inteiros e use is_triangle para verificar se os gravetos com os comprimentos dados podem formar um triângulo.

# %%
def is_triangle(a,b,c):
    if a + b < c or a + c < b or b + c < a:
        print("No")
    else: 
        print("Yes")

def lados():
    a = input('Digite um número inteiro: ')
    b = input('Digite um número inteiro: ')
    c = input('Digite um número inteiro: ')
    is_triangle(a,b,c)

lados()

# %% [markdown]
# Exercício 4: Leia a próxima função e veja se consegue compreender o que ela faz (veja os exemplos no Capítulo 4). Então execute-a e veja se acertou.

# %%
# !pip3 install ColabTurtle
import ColabTurtle

# %%
def draw(t, length, n):
    if n == 0:
        return
    angle = 50
    t.forward(length * n)
    t.left(angle)
    draw(t, length, n-1)
    t.right(2 * angle)
    draw(t, length, n-1)
    t.left(angle)
    t.backward(length * n)

import ColabTurtle.Turtle as pipa
pipa.initializeTurtle()

draw(pipa, 10, 5)

# %% [markdown]
# Exercício 5: A curva de Koch é um fractal que parece com o da figura abaixo. Para desenhar uma curva de Koch com o comprimento x, tudo o que você tem que fazer é:
#
# 1. Desenhe uma curva de Koch com o comprimento x/3.
#
# 2. Vire 60 graus à esquerda.
#
# 3. Desenhe uma curva de Koch com o comprimento x/3.
#
# 4. Vire 120 graus à direita.
#
# 5. Desenhe uma curva de Koch com o comprimento x/3.
#
# 6. Vire 60 graus à esquerda.
#
# 7. Desenhe uma curva de Koch com o comprimento x/3.
#
# A exceção é se x for menor que 3: neste caso, você pode desenhar apenas uma linha reta com o comprimento x.
#
# a) Escreva uma função chamada koch que receba um ColabTurtle (ou turtle) e um comprimento como parâmetros, e use o ColabTurtle para desenhar uma curva de Koch com o comprimento dado.
#
# b) Escreva uma função chamada snowflake que desenhe três curvas de Koch para fazer o traçado de um floco de neve.
#
# c) A curva de Koch pode ser generalizada de vários modos. Veja exemplos em http://en.wikipedia.org/wiki/Koch_snowflake e implemente o seu favorito.

# %%
# !pip3 install ColabTurtle
import ColabTurtle

# %%
import ColabTurtle.Turtle as bey
bey.initializeTurtle()
bey.color("blue")
bey.bgcolor("white")

def koch(bey, x):
    if x < 10:
      bey.forward(5)
      return
    n = x/3
    koch(bey, n)
    bey.left(60)
    koch(bey, n)
    bey.right(120)
    koch(bey, n)
    bey.left(60)
    koch(bey, n)

def snowflake(bey, n):
    for i in range(3):
        koch(bey, n)
        bey.right(120)

bey.penup()
bey.goto(300, 450)
bey.pendown()
snowflake(bey, 300)
bey.speed(10)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="white"/>
# ...
